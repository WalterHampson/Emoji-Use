# %%
# Import necessary libraries
import pandas as pd

# %%
# Load the emoji dataset
def load_dataset(file_path):
    # Load the dataset and return as a pandas dataframe
    df = pd.read_csv(file_path)
    return df

# Get the most popular emojis
def get_most_popular_emojis(df, top_n=10):
    # Count occurrences of each emoji
    emoji_counts = df['Emoji'].value_counts().reset_index()
    emoji_counts.columns = ['Emoji', 'Count']
    
    # Merge with the original dataframe to maintain context and other details
    popular_emojis = pd.merge(emoji_counts, df, on='Emoji').drop_duplicates('Emoji').sort_values(by='Count', ascending=False).head(top_n)
    return popular_emojis

# %%
# Display the context of the most popular emojis
def display_emoji_context(df):
    display("Most Popular Emojis and Their Contexts:\n")
    for index, row in df.iterrows():
        emoji = row['Emoji']
        count = row['Count']
        context = row['Context']
        platform = row['Platform']
        user_age = row['User Age']
        user_gender = row['User Gender']
        display(f"Emoji: {emoji} | Count: {count} | Context: {context} | Platform: {platform} | Age: {user_age} | Gender: {user_gender}\n")

# %%
# Analyze usage of emojis across different platforms, age groups, and genders
def analyze_emoji_by_demographics(df):
    display("\nEmoji Usage by Demographics:\n")
    
    # Group by emoji and platform
    platform_usage = df.groupby(['Emoji', 'Platform']).size().reset_index(name='Count')
    display("Platform Usage:\n", platform_usage)

    # Group by emoji and age group
    age_usage = df.groupby(['Emoji', 'User Age']).size().reset_index(name='Count')
    display("\nAge Group Usage:\n", age_usage)

    # Group by emoji and gender
    gender_usage = df.groupby(['Emoji', 'User Gender']).size().reset_index(name='Count')
    display("\nGender Usage:\n", gender_usage)

# %%
# Main function to execute the analysis
def analyze_emoji_usage(file_path, top_n=10):
    # Step 1: Load dataset
    df = load_dataset(file_path)

    # Step 2: Get the top N most popular emojis
    popular_emojis = get_most_popular_emojis(df, top_n)

    # Step 3: Display the context of the most popular emojis
    display_emoji_context(popular_emojis)

    # Step 4: Analyze usage by platform, age group, and gender
    analyze_emoji_by_demographics(df)

# %%
# Provide the file path of the emoji usage dataset
file_path = 'emoji_usage_dataset.csv'

# Analyze the emoji usage (Top 10 emojis)
analyze_emoji_usage(file_path, top_n=10)
# Out:
# 'Most Popular Emojis and Their Contexts:\n'
# 'Emoji: 🤣 | Count: 193 | Context: celebration | Platform: Snapchat | Age: 56 | Gender: Female\n'
# 'Emoji: 👏 | Count: 185 | Context: love | Platform: Twitter | Age: 16 | Gender: Male\n'
# 'Emoji: 😭 | Count: 184 | Context: support | Platform: Facebook | Age: 29 | Gender: Male\n'
# 'Emoji: 🙏 | Count: 184 | Context: surprise | Platform: WhatsApp | Age: 33 | Gender: Female\n'
# 'Emoji: 💕 | Count: 182 | Context: happy | Platform: WhatsApp | Age: 17 | Gender: Female\n'
# 'Emoji: 💔 | Count: 181 | Context: confusion | Platform: Snapchat | Age: 45 | Gender: Female\n'
# 'Emoji: 🤪 | Count: 178 | Context: celebration | Platform: Twitter | Age: 37 | Gender: Male\n'
# 'Emoji: 🎉 | Count: 177 | Context: sad | Platform: Facebook | Age: 37 | Gender: Female\n'
# 'Emoji: 😜 | Count: 176 | Context: surprise | Platform: TikTok | Age: 62 | Gender: Female\n'
# 'Emoji: 🤔 | Count: 176 | Context: confusion | Platform: Facebook | Age: 42 | Gender: Male\n'
# ...
